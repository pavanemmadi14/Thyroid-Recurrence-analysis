# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("C:\\Users\\pavan\\Downloads\\Thyroid_Diff.csv")
df
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
df["Age"].describe()
# Out:
# count    383.000000
# mean      40.866841
# std       15.134494
# min       15.000000
# 25%       29.000000
# 50%       37.000000
# 75%       51.000000
# max       82.000000
# Name: Age, dtype: float64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# F    312
# M     71
# Name: count, dtype: int64

# %%
df["Smoking"].value_counts()
# Out:
# Smoking
# No     334
# Yes     49
# Name: count, dtype: int64

# %%
#Hx Smoking whether a patient has a past history of smoking
df["Hx Smoking"].value_counts()
# Out:
# Hx Smoking
# No     355
# Yes     28
# Name: count, dtype: int64

# %%
#Hx Radiotherapy is whether the patient has a past medical history of receiving radiotherapy treatment (radiation-based medical treatment — often for cancer, tumors, thyroid issues, etc.
df["Hx Radiothreapy"].value_counts()
# Out:
# Hx Radiothreapy
# No     376
# Yes      7
# Name: count, dtype: int64

# %%
#"Thyroid Function" typically represents a categorical medical status describing how well a person’s thyroid gland is functioning based on clinical test results (TSH, T3, T4, FT4 levels)
df["Thyroid Function"].value_counts()
# Out:
# Thyroid Function
# Euthyroid                      332
# Clinical Hyperthyroidism        20
# Subclinical Hypothyroidism      14
# Clinical Hypothyroidism         12
# Subclinical Hyperthyroidism      5
# Name: count, dtype: int64

# %%
#"Physical Examination" represents the clinical observation/findings recorded by a doctor during a physical exam of the thyroid gland — usually by neck palpation (feeling the thyroid gland for swelling, nodules, size, or shape
df["Physical Examination"].value_counts()
# Out:
# Physical Examination
# Multinodular goiter            140
# Single nodular goiter-right    140
# Single nodular goiter-left      89
# Normal                           7
# Diffuse goiter                   7
# Name: count, dtype: int64

# %%
#"Adenopathy" refers to swollen or enlarged lymph nodes (usually in the neck area), which can happen due to thyroid disease or cancer spread
df["Adenopathy"].value_counts()
# Out:
# Adenopathy
# No           277
# Right         48
# Bilateral     32
# Left          17
# Extensive      7
# Posterior      2
# Name: count, dtype: int64

# %%
#"Pathology" column refers to the type of thyroid tumor or tissue diagnosis confirmed by medical lab examination
df["Pathology"].value_counts()
# Out:
# Pathology
# Papillary         287
# Micropapillary     48
# Follicular         28
# Hurthel cell       20
# Name: count, dtype: int64

# %%
#"Focality" column describes whether the thyroid disease/tumor is located in one place or in multiple places inside the thyroid gland
df["Focality"].value_counts()
# Out:
# Focality
# Uni-Focal      247
# Multi-Focal    136
# Name: count, dtype: int64

# %%
df["Risk"].value_counts()
# Out:
# Risk
# Low             249
# Intermediate    102
# High             32
# Name: count, dtype: int64

# %%
df["T"].value_counts()
# Out:
# T
# T2     151
# T3a     96
# T1a     49
# T1b     43
# T4a     20
# T3b     16
# T4b      8
# Name: count, dtype: int64

# %%
df["N"].value_counts()
# Out:
# N
# N0     268
# N1b     93
# N1a     22
# Name: count, dtype: int64

# %%
df["M"].value_counts()
# Out:
# M
# M0    365
# M1     18
# Name: count, dtype: int64

# %%
df["Stage"].value_counts()
# Out:
# Stage
# I      333
# II      32
# IVB     11
# III      4
# IVA      3
# Name: count, dtype: int64

# %%
df["Response"].value_counts()
# Out:
# Response
# Excellent                 208
# Structural Incomplete      91
# Indeterminate              61
# Biochemical Incomplete     23
# Name: count, dtype: int64

# %%
df["Recurred"].value_counts()
# Out:
# Recurred
# No     275
# Yes    108
# Name: count, dtype: int64

# %%
#In dataset 1 continous variable and 16 categorical variables are present

# %%
df["Age"].describe()
# Out:
# count    383.000000
# mean      40.866841
# std       15.134494
# min       15.000000
# 25%       29.000000
# 50%       37.000000
# 75%       51.000000
# max       82.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(y=df["Age"])
plt.show()

# %%
df.describe()
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
#Handling missing values
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
#If missing values present 
#df.dropna(inplace=True)  For removing rows with missing values
#df["Age"]=df["Age"].fillna(df["Age"].mean())   for replacing if continous varible
#df["Gender"]=df["Gender"].fillna(df["Gender"].mode()) for replacing if categorical variable

# %%
#Handling duplicates
df.drop_duplicates()
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
#It contains total of 19 duplicate rows in dataset
df[df.duplicated()]
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 32    36      F      No         No              No        Euthyroid
# 38    40      F      No         No              No        Euthyroid
# 40    51      F      No         No              No        Euthyroid
# 66    35      F      No         No              No        Euthyroid
# 69    51      F      No         No              No        Euthyroid
# 77    29      F      No         No              No        Euthyroid
# 120   37      F      No         No              No        Euthyroid
# 121   26      F      No         No              No        Euthyroid
# 123   28      F      No         No              No        Euthyroid
# 132   32      F      No         No              No        Euthyroid
# 137   32      F      No         No              No        Euthyroid
# 138   26      F      No         No              No        Euthyroid
# 166   31      F      No         No              No        Euthyroid
# ...

# %%
#to hanldle duplicate data we use
df1=df.duplicated()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
#Handling incorrect Data types
#In our dataset there is no incorrect data type
#If incorrect data type present to hanlde we will do
#df['Age'] = df['Age'].astype(int)     if 'Age'
#df['Date'] = pd.to_datetime(df['Date'])

# %%
#Here we observe that the most of the adults are getting effected by thyroid
plt.hist(x=df["Age"])
plt.title("Age distribution of Thyroid")
plt.show()

# %%
# Here below shows females are more effected
sns.countplot(x=df["Gender"])
plt.title("Gender Distribution")
plt.ylabel("Count")
plt.xlabel("Gender")8
plt.show()

# %%
#smoking is not a factor that cause thyroid
sns.countplot(x="Smoking",data=df)
plt.title("Current Smokers Distribution")
plt.show()

# %%
#the mojority is non smokers with no prior history of smoking
.countplot(x="Smoking",hue="Hx Smoking",data=df)
plt.title("Current Smokers and History of Smokers Distribution")
plt.show()sns

# %%
labels=['Low','Intermediate','High']
Risk_counts=df["Risk"].value_counts()
explode=[0,0,0.1]
plt.pie(Risk_counts,labels=labels,explode=explode,data=df,autopct='%1.1f%%')
plt.show()

# %%
sns.countplot(x=df["Stage"])
plt.title("Stage Distribution")
plt.show()

# %%
sns.boxplot(x="Response",y="Age",data=df)
plt.title("Age Vs Response")
plt.xticks(rotation=30)
plt.show()

# %%
sns.countplot(x="Recurred",data=df)
plt.title("Distribution of recurrence")
plt.show()

# %%
sns.countplot(x="Stage", hue="Recurred",data=df)
plt.title("Stage VS Recurrence")
plt.show()

# %%
sns.boxplot(x="Thyroid Function",y="Age",data=df,)
plt.title("Age Vs Thyroid Function")
plt.xticks(rotation=30)
plt.show()

# %%
sns.boxplot(x="Physical Examination",y="Age",data=df)
plt.title("Age Vs Physical Examination")
plt.xticks(rotation=30)
plt.show()
